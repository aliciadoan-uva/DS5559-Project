# %%
# set data directory
data_dir = "../data"

# import python libraries
import os
import pandas as pd
import numpy as np
from functools import reduce

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# set up pyspark
from pyspark.sql import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.getOrCreate()

# %%
# %%time
NHAMCS = spark.read.parquet(data_dir + "/NHAMCS.2007-2017")
# Out:
# CPU times: user 2.54 ms, sys: 740 µs, total: 3.28 ms
# Wall time: 5.25 s

# %%
NHAMCS.take(2)
# Out:
# [Row(VMONTH='July', VYEAR=2009, VDAYR='Saturday', AGE='36', ARRTIME=2125, WAITTIME='5', LOV='296', RESIDNCE='Private residence', SEX='Female', ETHUN='Not Hispanic or Latino', RACEUN='Black/African American Only', ARRIVE=None, PAYPRIV='No', PAYMCARE='No', PAYMCAID='No', PAYWKCMP='No', PAYSELF='No', PAYNOCHG='No', PAYOTH='Yes', PAYDK='No', PAYTYPE=None, TEMPF='97.9', PULSE='84', RESPR='18', BPSYS='132', BPDIAS='93', POPCT='99', ORIENTED=None, IMMED=None, PAIN=None, SEEN72='No', DISCH7DA='No', PASTVIS='Unknown', RFV1='Side pain, flank pain', RFV2='Blank', RFV3='Blank', RFV13D='Pain, site not referable to a specifi...', RFV23D='Blank', RFV33D='Blank', EPISODE='Initial visit', INJURY='No', INTENT='Not applicable/Not an injury visit', CAUSE1='-9', CAUSE2='-9', CAUSE3='-9', CAUSE13D=-9, CAUSE23D=-9, CAUSE33D=-9, VCAUSE='-9', DIAG1='78652', DIAG2='-9', DIAG3='-9', DIAG13D='786', DIAG23D='-9', DIAG33D='-9', PRDIAG1='No', PRDIAG2='Not applicable', PRDIAG3='Not applicable', DIAGSCRN='Yes', CBC='Yes', BUNCREAT='No', CARDENZ='No', ELECTROL='No', GLUCOSE='No', LFT='No', ABG='No', PTTINR='No', BLOODCX='No', BAC='No', TOXSCREN='No', OTHERBLD='Yes', CARDMON='No', EKG='No', PREGTEST='No', FLUTEST='No', URINE='No', WOUNDCX='No', OTHRTEST='No', ANYIMAGE='Yes', XRAY='Yes', CATSCAN='No', CTHEAD='No', CTNHEAD='No', CTUNK='No', MRI='No', MRIHEAD=None, MRINHEAD=None, MRIUNK=None, ULTRASND='No', OTHIMAGE='No', TOTDIAG='3', PROC='Yes', IVFLUIDS='Yes', CAST='No', SPLINT='No', LACREP=None, INCDRAIN='No', DEBRIDE=None, FBREM='No', NEBUTHER='No', BLADCATH='No', NGTUBE=None, CPR='No', ENDOINT='No', OTHPROC='No', TOTPROC='1', MED='Yes', MED1='DILAUDID', MED2='NORMAL SALINE', MED3='NO ENTRY MADE', MED4='NO ENTRY MADE', MED5='NO ENTRY MADE', MED6='NO ENTRY MADE', MED7='NO ENTRY MADE', MED8='NO ENTRY MADE', GPMED1='Given in  ED', GPMED2='Given in  ED', GPMED3='Not applicable, no medication listed', GPMED4='Not applicable, no medication listed', GPMED5='Not applicable, no medication listed', GPMED6='Not applicable, no medication listed', GPMED7='Not applicable, no medication listed', GPMED8='Not applicable, no medication listed', NUMGIV='2', NUMDIS='None listed/listed drug given at ED only or unknown', NUMMED=2, NOPROVID='No', ATTPHYS='Yes', RESINT='No', ONCALL=None, RNLPN='Yes', NURSEPR='No', PHYSASST='No', EMT='No', OTHPROV='Yes', NODISP='One or more answers to the disposition item', NOFU='No', RETPRN='No', RETREFFU='No', REFSOCS=None, LEFTBMSE='No', LEFTAMSE='No', LEFTAMA='No', DOA='No', DIEDED='No', TRANSFER=None, RFTRANS=None, ADMITOBS=None, ADMITHOS='Yes', OTHDISP='No', ADMIT='Unknown (data not available)', LOS='1', HDDIAG='33829', HDSTAT='Alive', ADISP='Home/Residence', PATWT='10162', REGION='Midwest', MSA='MSA (Metropolitan Statistical Area)', OWNER='Voluntary non-profit', BLANK1='NA', BLANK2='NA', BLANK3='NA', HOSPCODE='1', PATCODE=118, BDATEFL='Not imputed', SEXFL='Not imputed', ETHNICFL='Not imputed', RACEFL=None, IMMEDFL=None, DRUGID1='d00255', PRESCR1='Prescription drug', CONTSUB1='Schedule II', COMSTAT1='Single entity drug', RX1CAT1='60', RX1CAT2=None, RX1CAT3=None, RX1CAT4=None, RX1V1C1=57, RX1V1C2=None, RX1V1C3=None, RX1V1C4=None, RX1V2C1=58, RX1V2C2=None, RX1V2C3=None, RX1V2C4=None, RX1V3C1=60, RX1V3C2=None, RX1V3C3=None, RX1V3C4=None, DRUGID2='d00438', PRESCR2='Prescription or Nonprescription drug', CONTSUB2='No control', COMSTAT2='Single entity drug', RX2CAT1='117', RX2CAT2=129, RX2CAT3=None, RX2CAT4=None, RX2V1C1=115, RX2V1C2=122, RX2V1C3=None, RX2V1C4=None, RX2V2C1=117, RX2V2C2=129, RX2V2C3=None, RX2V2C4=None, RX2V3C1=None, RX2V3C2=None, RX2V3C3=None, RX2V3C4=None, DRUGID3=None, PRESCR3='NA', CONTSUB3='NA', COMSTAT3='NA', RX3CAT1=None, RX3CAT2=None, RX3CAT3=None, RX3CAT4=None, RX3V1C1=None, RX3V1C2=None, RX3V1C3=None, RX3V1C4=None, RX3V2C1=None, RX3V2C2=None, RX3V2C3=None, RX3V2C4=None, RX3V3C1=None, RX3V3C2=None, RX3V3C3=None, RX3V3C4=None, DRUGID4=None, PRESCR4='NA', CONTSUB4='NA', COMSTAT4='NA', RX4CAT1=None, RX4CAT2=None, RX4CAT3=None, RX ...
#  Row(VMONTH='July', VYEAR=2009, VDAYR='Friday', AGE='40', ARRTIME=1904, WAITTIME='5', LOV='86', RESIDNCE='Private residence', SEX='Female', ETHUN='Not Hispanic or Latino', RACEUN='White Only', ARRIVE=None, PAYPRIV='Yes', PAYMCARE='No', PAYMCAID='No', PAYWKCMP='No', PAYSELF='No', PAYNOCHG='No', PAYOTH='No', PAYDK='No', PAYTYPE=None, TEMPF='99.1', PULSE='90', RESPR='16', BPSYS='129', BPDIAS='75', POPCT='99', ORIENTED=None, IMMED=None, PAIN=None, SEEN72='No', DISCH7DA='No', PASTVIS='Unknown', RFV1='Neck pain, ache, soreness, discomfort', RFV2='Low back pain, ache, soreness, discom...', RFV3='Blank', RFV13D='Neck symptoms', RFV23D='Low back symptoms', RFV33D='Blank', EPISODE='Initial visit', INJURY='Yes', INTENT='No, unintentional', CAUSE1='8121', CAUSE2='8495', CAUSE3='-9', CAUSE13D=812, CAUSE23D=849, CAUSE33D=-9, VCAUSE='MVA-RESTRAINED PASSENGER REAR-ENDED AT STOPLIGHT-DENIES LOC', DIAG1='-9', DIAG2='-9', DIAG3='-9', DIAG13D='-9', DIAG23D='-9', DIAG33D='-9', PRDIAG1='Not applicable', PRDIAG2='Not applicable', PRDIAG3='Not applicable', DIAGSCRN='Yes', CBC='No', BUNCREAT='No', CARDENZ='No', ELECTROL='No', GLUCOSE='No', LFT='No', ABG='No', PTTINR='No', BLOODCX='No', BAC='No', TOXSCREN='No', OTHERBLD='No', CARDMON='No', EKG='No', PREGTEST='No', FLUTEST='No', URINE='No', WOUNDCX='No', OTHRTEST='No', ANYIMAGE='Yes', XRAY='Yes', CATSCAN='Yes', CTHEAD='No', CTNHEAD='Yes', CTUNK='No', MRI='No', MRIHEAD=None, MRINHEAD=None, MRIUNK=None, ULTRASND='No', OTHIMAGE='No', TOTDIAG='2', PROC='Yes', IVFLUIDS='Yes', CAST='No', SPLINT='No', LACREP=None, INCDRAIN='No', DEBRIDE=None, FBREM='No', NEBUTHER='No', BLADCATH='No', NGTUBE=None, CPR='No', ENDOINT='No', OTHPROC='No', TOTPROC='1', MED='Yes', MED1='NORMAL SALINE', MED2='DARVOCET-N', MED3='NO ENTRY MADE', MED4='NO ENTRY MADE', MED5='NO ENTRY MADE', MED6='NO ENTRY MADE', MED7='NO ENTRY MADE', MED8='NO ENTRY MADE', GPMED1='Given in  ED', GPMED2='RX at discharge', GPMED3='Not applicable, no medication listed', GPMED4='Not applicable, no medication listed', GPMED5='Not applicable, no medication listed', GPMED6='Not applicable, no medication listed', GPMED7='Not applicable, no medication listed', GPMED8='Not applicable, no medication listed', NUMGIV='1', NUMDIS='1', NUMMED=2, NOPROVID='No', ATTPHYS='Yes', RESINT='No', ONCALL=None, RNLPN='Yes', NURSEPR='No', PHYSASST='No', EMT='Yes', OTHPROV='Yes', NODISP='One or more answers to the disposition item', NOFU='No', RETPRN='Yes', RETREFFU='No', REFSOCS=None, LEFTBMSE='No', LEFTAMSE='No', LEFTAMA='No', DOA='No', DIEDED='No', TRANSFER=None, RFTRANS=None, ADMITOBS=None, ADMITHOS='No', OTHDISP='No', ADMIT='Not applicable', LOS='Not Applicable', HDDIAG='-7', HDSTAT='Not applicable', ADISP='Not applicable', PATWT='10162', REGION='Midwest', MSA='MSA (Metropolitan Statistical Area)', OWNER='Voluntary non-profit', BLANK1='NA', BLANK2='NA', BLANK3='NA', HOSPCODE='1', PATCODE=117, BDATEFL='Not imputed', SEXFL='Not imputed', ETHNICFL='Not imputed', RACEFL=None, IMMEDFL=None, DRUGID1='d00438', PRESCR1='Prescription or Nonprescription drug', CONTSUB1='No control', COMSTAT1='Single entity drug', RX1CAT1='117', RX1CAT2=129, RX1CAT3=None, RX1CAT4=None, RX1V1C1=115, RX1V1C2=122, RX1V1C3=None, RX1V1C4=None, RX1V2C1=117, RX1V2C2=129, RX1V2C3=None, RX1V2C4=None, RX1V3C1=None, RX1V3C2=None, RX1V3C3=None, RX1V3C4=None, DRUGID2='d03434', PRESCR2='Prescription drug', CONTSUB2='Schedule IV', COMSTAT2='Combination drug', RX2CAT1='191', RX2CAT2=None, RX2CAT3=None, RX2CAT4=None, RX2V1C1=57, RX2V1C2=None, RX2V1C3=None, RX2V1C4=None, RX2V2C1=58, RX2V2C2=None, RX2V2C3=None, RX2V2C4=None, RX2V3C1=191, RX2V3C2=None, RX2V3C3=None, RX2V3C4=None, DRUGID3=None, PRESCR3='NA', CONTSUB3='NA', COMSTAT3='NA', RX3CAT1=None, RX3CAT2=None, RX3CAT3=None, RX3CAT4=None, RX3V1C1=None, RX3V1C2=None, RX3V1C3=None, RX3V1C4=None, RX3V2C1=None, RX3V2C2=None, RX3V2C3=None, RX3V2C4=None, RX3V3C1=None, RX3V3C2=None, RX3V3C3=None, RX3V3C4=None, DRUGID4=None, PRESCR4='NA', CONTSUB4='NA', COMSTAT4='NA', RX4CAT1=None ...
